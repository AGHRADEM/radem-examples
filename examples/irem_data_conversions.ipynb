# %% [markdown]
# # IREM Data Conversion with the `radem` library

# %% [markdown]
# ## 1. Download IREM data (optional)
#
# In this section, we will guide you through the process of downloading IREM data (if you haven't downloaded it already).
#
# - This cell supports Linux-based operating systems, for other OSes you can download the data manually.
# - We will use the `wget` command to fetch the data from the official [IREM data repository](http://srem.psi.ch/datarepo/V0/irem/).
# - The data will be organized into directories for original raw data, and extracted CDF data. You can modify the `DATA_DIR` variable to change the location of the data.
# - Additionally, we will ensure that existing files are not downloaded again to save time and bandwidth.
# - Running this cell the first time can take a while, grab a coffee.

# %%
# %%sh
# # Data directory to store the data
# DATA_DIR="../data/irem"
#
# # Creating data directories
# mkdir -p ${DATA_DIR}
# mkdir -p ${DATA_DIR}/extracted
#
# # Create a symlink to the raw directory
# DATA_RAW_DIR=${DATA_DIR}/raw
# if [ ! -L "$DATA_RAW_DIR" ]; then
#     ABS_DATA_RAW_DIR=$(readlink -f ${DATA_RAW_DIR})
#     ABS_DATA_DIR=$(readlink -f ${DATA_DIR})
#     ln -s ${ABS_DATA_DIR}/srem.psi.ch/datarepo/V0/irem ${ABS_DATA_RAW_DIR}
# fi
#
# # Get data recursively, don't download existing files
# wget \
#     --recursive \
#     --no-parent \
#     --continue \
#     --no-clobber \
#     --no-verbose \
#     -A gz \
#     http://srem.psi.ch/datarepo/V0/irem/ \
#     -P ${DATA_DIR} \
#     2> ${DATA_DIR}/wget.log # Redirect wget output to a log file to avoid cluttering the notebook
#
# # Remove summary plots dir which we don't care about
# rm -rf ${DATA_DIR}/irem/raw/summaryplots

# %% [markdown]
# ## 2. Notebook setup

# %%
import os
from pathlib import Path
from typing import List
import gzip

DATA_DIR = Path("../data/irem")
DATA_RAW_DIR = DATA_DIR / "raw"
DATA_EXTRACTED_DIR = DATA_DIR / "extracted"

# %% [markdown]
# ## 2. Extract CDF data

# %%
def get_data_raw_filenames(data_raw_dir: Path) -> List[Path]:
    filenames = [data_raw_dir / dirname / filename
                    for dirname in os.listdir(data_raw_dir)
                    for filename in os.listdir(data_raw_dir / dirname)
                    if filename.endswith(".cdf.gz")]
    filenames_sorted = sorted(filenames)
    return filenames_sorted

def extract_data_raw_file(input_filename: Path, output_filename: Path) -> None:
    with open(input_filename, 'rb') as f_in:
        with gzip.open(f_in) as f_decompressed, open(output_filename, 'wb') as f_out:
            f_out.write(f_decompressed.read())

def extract_data_raw_files(data_raw_filenames: List[Path], data_extracted_dir: Path) -> None:
    for filename in data_raw_filenames:
        output_filename = data_extracted_dir / filename.stem
        if not output_filename.exists():
            print(f"Extracting {filename} to {output_filename}")
            extract_data_raw_file(filename, output_filename)
        else:
            print(
                f"Skipping extracting {output_filename} - already exists.")

extract_data_raw_files(
    get_data_raw_filenames(DATA_RAW_DIR),
    DATA_EXTRACTED_DIR)
# Out:
# Skipping extracting ../data/irem/extracted/IREM_PACC_20021017.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20021018.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20021019.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20021020.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20021021.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20021022.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20021023.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20021024.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20021025.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20021026.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20021027.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20021028.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20021029.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20021030.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20021031.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20021101.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20021102.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20021103.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20021104.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20021105.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20021106.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20021107.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20021108.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20021109.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20021110.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20021111.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20021112.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20021113.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20021114.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20021115.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20021116.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20021117.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20021118.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20021119.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20021120.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20021121.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20021122.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20021123.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20021124.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20021125.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20021126.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20021127.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20021128.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20021129.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20021130.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20021201.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20021202.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20021203.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20021204.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20021205.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20021206.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20021207.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20021208.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20021209.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20021210.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20021211.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20021212.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20021213.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20021214.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20021215.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20021216.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20021217.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20021218.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20021219.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20021220.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20021221.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20021222.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20021223.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20021224.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20021225.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20021226.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20021227.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20021228.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20021229.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20021230.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20021231.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030101.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030102.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030103.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030104.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030105.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030106.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030107.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030108.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030109.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030110.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030111.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030112.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030113.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030114.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030115.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030116.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030117.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030118.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030119.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030120.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030121.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030122.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030123.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030124.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030125.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030126.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030127.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030128.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030128_exp.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030128_pow.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030129.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030130.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030131.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030131_exp.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030131_pow.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030201.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030202.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030203.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030204.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030205.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030206.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030207.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030208.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030209.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030210.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030211.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030212.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030213.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030214.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030215.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030216.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030217.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030218.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030219.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030220.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030221.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030222.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030223.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030224.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030225.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030226.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030227.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030228.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030301.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030302.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030303.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030304.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030305.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030306.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030307.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030308.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030309.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030310.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030311.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030312.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030313.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030314.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030315.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030317.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030318.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030319.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030320.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030321.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030322.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030323.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030324.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030325.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030326.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030327.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030328.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030329.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030330.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030331.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030401.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030401_exp.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030401_pow.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030402.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030403.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030404.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030405.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030406.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030407.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030408.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030409.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030410.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030411.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030412.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030413.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030414.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030415.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030416.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030417.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030418.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030419.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030420.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030421.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030422.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030423.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030424.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030425.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030426.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030427.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030428.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030429.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030430.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030501.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030502.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030503.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030504.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030505.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030506.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030507.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030508.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030509.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030510.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030511.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030512.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030513.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030514.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030515.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030516.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030517.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030518.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030519.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030520.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030521.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030522.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030523.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030524.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030525.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030526.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030527.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030528.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030529.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030530.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030531.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030601.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030602.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030603.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030604.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030605.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030606.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030607.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030608.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030609.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030610.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030611.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030612.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030613.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030614.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030615.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030616.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030617.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030618.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030619.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030620.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030621.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030622.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030623.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030624.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030625.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030626.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030627.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030628.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030629.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030630.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030701.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030702.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030703.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030704.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030705.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030706.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030707.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030708.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030709.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030710.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030711.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030712.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030713.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030714.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030715.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030716.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030717.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030718.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030719.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030720.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030721.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030722.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030723.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030724.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030725.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030726.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030727.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030728.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030729.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030730.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030731.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030801.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030802.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030803.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030804.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030805.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030806.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030807.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030808.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030809.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030810.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030811.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030812.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030813.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030814.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030815.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030816.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030817.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030818.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030819.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030820.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030821.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030822.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030823.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030824.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030825.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030826.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030827.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030828.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030829.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030830.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030831.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030901.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030902.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030903.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030904.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030905.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030906.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030907.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030908.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030909.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030910.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030911.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030912.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030913.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030914.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030915.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030916.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030917.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030918.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030919.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030920.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030921.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030922.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030923.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030924.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030925.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030926.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030927.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030928.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030929.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20030930.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031001.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031002.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031003.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031004.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031005.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031006.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031007.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031008.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031009.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031010.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031011.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031012.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031013.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031014.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031015.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031016.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031017.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031018.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031019.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031020.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031021.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031022.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031023.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031024.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031025.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031026.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031027.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031028.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031029.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031030.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031031.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031101.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031102.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031103.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031104.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031105.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031106.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031107.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031108.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031109.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031110.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031111.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031112.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031113.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031114.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031115.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031116.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031117.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031118.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031119.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031120.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031121.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031122.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031123.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031124.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031125.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031126.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031127.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031128.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031129.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031130.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031201.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031202.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031203.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031204.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031205.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031206.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031207.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031208.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031209.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031210.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031211.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031212.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031213.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031214.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031215.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031216.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031217.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031218.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031219.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031220.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031221.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031222.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031223.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031224.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031225.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031226.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031227.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031229.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031230.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20031231.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040101.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040102.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040103.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040104.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040105.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040106.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040107.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040108.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040109.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040110.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040111.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040112.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040113.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040114.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040115.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040116.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040117.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040118.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040119.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040120.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040121.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040122.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040123.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040124.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040125.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040126.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040127.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040128.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040129.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040130.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040131.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040201.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040202.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040203.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040204.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040205.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040206.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040207.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040208.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040209.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040210.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040211.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040212.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040213.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040214.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040215.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040216.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040217.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040218.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040219.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040220.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040221.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040222.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040223.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040224.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040225.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040226.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040227.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040228.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040301.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040302.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040303.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040304.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040305.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040306.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040307.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040308.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040309.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040310.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040311.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040312.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040313.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040314.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040315.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040316.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040317.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040318.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040319.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040320.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040321.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040322.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040323.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040324.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040325.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040326.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040327.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040328.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040329.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040330.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040331.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040401.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040402.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040403.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040404.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040405.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040406.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040407.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040408.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040409.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040410.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040411.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040412.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040413.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040414.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040415.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040416.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040417.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040418.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040419.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040420.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040421.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040422.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040423.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040424.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040425.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040426.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040427.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040428.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040429.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040430.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040501.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040502.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040503.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040504.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040505.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20040506.cdf - already exists.
# ...
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240520.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240521.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240522.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240523.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240524.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240525.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240526.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240527.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240528.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240529.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240530.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240531.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240601.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240602.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240603.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240604.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240605.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240606.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240607.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240608.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240609.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240610.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240611.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240612.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240613.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240614.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240615.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240616.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240617.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240618.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240619.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240620.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240621.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240622.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240623.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240624.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240625.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240626.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240627.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240628.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240629.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240630.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240701.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240702.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240703.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240704.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240705.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240706.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240707.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240708.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240709.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240710.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240711.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240712.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240713.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240714.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240715.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240716.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240717.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240718.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240719.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240720.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240721.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240722.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240723.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240724.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240725.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240726.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240727.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240728.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240729.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240730.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240731.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240801.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240802.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240803.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240804.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240805.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240806.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240807.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240808.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240809.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240810.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240811.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240812.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240813.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240814.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240815.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240816.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240817.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240818.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240819.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240820.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240821.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240822.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240823.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240824.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240825.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240826.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240827.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240828.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240829.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240830.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240831.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240901.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240902.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240903.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240904.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240905.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240906.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240907.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240908.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240909.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240910.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240911.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240912.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240913.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240914.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240915.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240916.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240917.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240918.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240919.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240920.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240921.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240922.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240923.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240924.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240925.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240926.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240927.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240928.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240929.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20240930.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20241001.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20241002.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20241003.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20241004.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20241005.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20241006.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20241007.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20241008.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20241009.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20241010.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20241011.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20241012.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20241013.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20241014.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20241015.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20241016.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20241017.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20241018.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20241019.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20241020.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20241021.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20241022.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20241023.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20241024.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20241025.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20241026.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20241027.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20241028.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20241029.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20241030.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20241031.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20241101.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20241102.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20241103.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20241104.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20241105.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20241106.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20241107.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20241108.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20241109.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20241110.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20241111.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20241112.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20241113.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20241114.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20241115.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20241116.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20241117.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20241118.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20241119.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20241120.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20241121.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20241122.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20241123.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20241124.cdf - already exists.
# Skipping extracting ../data/irem/extracted/IREM_PACC_20241125.cdf - already exists.

# %%
## 3.
